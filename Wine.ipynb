# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
! rm -r adult*
# Out:
# rm: adult*: No such file or directory

# %%
df = pd.read_csv("winequality-red.csv", sep=';') 
df

# %%
df.isna().sum()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df=(df-df.min())/(df.max()-df.min())

# %%
df

# %%
df.corr()

# %%
sns.heatmap(df.corr(), annot=True)

# %%
plt.rcParams["figure.figsize"] = (12,10)

# %%
plt.pie(df['quality'].value_counts(), autopct="%.2f",labels=df['quality'].unique()*10) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b44c25c22977> in <module>
# ----> 1 plt.pie(df['quality'].value_counts(), autopct="%.2f",labels=df['quality'].unique()*10)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.histplot(df['alcohol'], kde=True)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
df['alcohol'].hist()
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
df['quality'].value_counts().plot.pie()
fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
sns.boxplot(y = df['alcohol'], x=df['quality'])
fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sns.violinplot(y = df['alcohol'], x=df['quality'])
# Out:
# <Axes3DSubplot:xlabel='quality', ylabel='alcohol'>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['alcohol'], df['quality'], df['pH'], c='red', s=50)
plt.xlabel("alcohol")
plt.ylabel("quality")


plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
plt.figure()
x = [1,2,3]
y = [4,5,6]
plt.plot(x,y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sklearn.model_selection import train_test_split

# %%
 df[:1]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.247788           0.39726          0.0        0.068493   0.106845
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.140845               0.09894  0.567548  0.606299   0.137725
#
#     alcohol  quality
# 0  0.153846      0.4

# %%
a = df['quality']>= 0.5

# %%
a
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1594    False
# 1595     True
# 1596     True
# 1597    False
# 1598     True
# Name: quality, Length: 1599, dtype: bool

# %%
df[a]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 7          0.238938          0.363014         0.00        0.020548   0.088481
# 8          0.283186          0.315068         0.02        0.075342   0.101836
# 16         0.345133          0.109589         0.56        0.061644   0.133556
# 19         0.292035          0.136986         0.51        0.061644   0.549249
# ...             ...               ...          ...             ...        ...
# 1592       0.150442          0.267123         0.13        0.095890   0.106845
# 1593       0.194690          0.342466         0.08        0.068493   0.093489
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
df[(df['quality'] >= 0.5) & (df['alcohol']>0.2)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 7          0.238938          0.363014         0.00        0.020548   0.088481
# 16         0.345133          0.109589         0.56        0.061644   0.133556
# 29         0.283186          0.359589         0.00        0.075342   0.116861
# 31         0.203540          0.386986         0.00        0.109589   0.155259
# ...             ...               ...          ...             ...        ...
# 1591       0.070796          0.424658         0.09        0.054795   0.128548
# 1592       0.150442          0.267123         0.13        0.095890   0.106845
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
df.iloc[3:5,4]
# Out:
# 3    0.105175
# 4    0.106845
# Name: chlorides, dtype: float64

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
Y = df.iloc[:,-1]

# %%
df.iloc[:,:-1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
X = df.iloc[:,:-1]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
Y
# Out:
# 0       0.4
# 1       0.4
# 2       0.4
# 3       0.6
# 4       0.4
#        ...
# 1594    0.4
# 1595    0.6
# 1596    0.6
# 1597    0.4
# 1598    0.6
# Name: quality, Length: 1599, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

# %%
df.iloc[:,11:]
# Out:
#       quality
# 0         0.4
# 1         0.4
# 2         0.4
# 3         0.6
# 4         0.4
# ...       ...
# 1594      0.4
# 1595      0.6
# 1596      0.6
# 1597      0.4
# 1598      0.6
#
# [1599 rows x 1 columns]

# %%
df.quality.value_counts()
# Out:
# 0.4    681
# 0.6    638
# 0.8    199
# 0.2     53
# 1.0     18
# 0.0     10
# Name: quality, dtype: int64

# %% [markdown]
# acha okay then. my bad. buuuutt regression also makes sense... it would output quality like 6.8 too tho... oh no :3.m
# Morethings to consider
# 1. we dont have data (training) for 0.3 0.5 0.7 0.9 etc so lassification breaks. also 10 output categories is bad xD
# 2. So we should stick to regression... or turn quality into 3 bins (bad, fair, good) for classification

# %%
from sklearn.linear_model import LinearRegression

# %%
for everything in sklearn it goes like this...

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.3644068963862268

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor()
sgd.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
sgd.score(X_test, y_test)
# Out:
# 0.1973047881715857

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test, sgd.predict(X_test)))
# Out:
# 0.14298758596634026

# %%
fig = plt.figure()
sns.regplot(x = X_test['alcohol'], y= y_test)
fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sklearn.neural_network import MLPRegressor

# %%
nn = MLPRegressor(hidden_layer_sizes=(100,50,10))

# %%
nn.fit(X_train, y_train)
nn.score(X_test, y_test)
# Out:
# 0.35625275311910276

# %%
but this is a multi layer perceptron.. the very edge of ML xD oh

# %%
from sklearn.inspection import plot_partial_dependence

# %%
plot_partial_dependence(nn, X_test, ["alcohol", "density"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

# %%
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
svr.score(X_test, y_test)
# Out:
# 0.40673436390711093

# %%
from sklearn.metrics import

# %%
np.sqrt(mean_squared_error(y_test, svr.predict(X_test)))
# Out:
# 0.12292708821460785
